# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px 
# %matplotlib inline

# %%
customers = pd.read_csv('olist_customers_dataset.csv')
orders = pd.read_csv('olist_orders_dataset.csv')
items = pd.read_csv('olist_order_items_dataset.csv')

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
ttask1 = orders.groupby('customer_id').agg({'order_id':'count'})
ttask1
# Out:
#                                   order_id
# customer_id
# 00012a2ce6f8dcda20d059ce98491703         1
# 000161a058600d5901f007fab4c27140         1
# 0001fd6190edaaf884bcaf3d49edf079         1
# 0002414f95344307404f0ace7a26f1d5         1
# 000379cdec625522490c315e70c7a9fb         1
# ...                                    ...
# fffecc9f79fd8c764f843e9951b11341         1
# fffeda5b6d849fbd39689bb92087f431         1
# ffff42319e9b2d713724ae527742af25         1
# ffffa3172527f765de70084a7e53aae8         1
# ffffe8b65bbe3087b653a978c870db99         1
#
# [99441 rows x 1 columns]

# %%
ttask1[ttask1 == 1]
# Out:
#                                   order_id
# customer_id
# 00012a2ce6f8dcda20d059ce98491703         1
# 000161a058600d5901f007fab4c27140         1
# 0001fd6190edaaf884bcaf3d49edf079         1
# 0002414f95344307404f0ace7a26f1d5         1
# 000379cdec625522490c315e70c7a9fb         1
# ...                                    ...
# fffecc9f79fd8c764f843e9951b11341         1
# fffeda5b6d849fbd39689bb92087f431         1
# ffff42319e9b2d713724ae527742af25         1
# ffffa3172527f765de70084a7e53aae8         1
# ffffe8b65bbe3087b653a978c870db99         1
#
# [99441 rows x 1 columns]

# %%
orders.customer_id.nunique()
# Out:
# 99441

# %%
#Ответ на пункт 1: 99441

# %%
#task 2

# %%
orders.order_status.unique()
# Out:
# array(['delivered', 'invoiced', 'shipped', 'processing', 'unavailable',
#        'canceled', 'created', 'approved'], dtype=object)

# %%
orders.query('order_status == ["canceled","unavailable"]').groupby('order_status')

# %%
gg = orders.query('order_status !="delivered"').groupby('order_status',as_index=False).agg({'order_id':'count'})
gg
# Out:
#   order_status  order_id
# 0     approved         2
# 1     canceled       625
# 2      created         5
# 3     invoiced       314
# 4   processing       301
# 5      shipped      1107
# 6  unavailable       609

# %%
sns.set(
    font_scale = 2,
    style = "whitegrid",
    rc = {'figure.figsize':(20,7)}
)

# %%
sns.barplot(data=gg, x='order_status',y='order_id')

# %%
# TASK 3

# %%
orders['order_purchase_timestamp'] = pd.to_datetime(orders['order_purchase_timestamp'])

# %%
orders['order_approved_at'] = pd.to_datetime(orders['order_approved_at'])

# %%
orders['order_delivered_carrier_date'] = pd.to_datetime(orders['order_delivered_carrier_date'])
orders['order_delivered_customer_date'] = pd.to_datetime(orders['order_delivered_customer_date'])
orders['order_estimated_delivery_date'] = pd.to_datetime(orders['order_estimated_delivery_date'])

# %%
orders['order_purchase_timestamp'].dt.day_name()
# Out:
# 0           Monday
# 1          Tuesday
# 2        Wednesday
# 3         Saturday
# 4          Tuesday
#            ...
# 99436     Thursday
# 99437      Tuesday
# 99438       Sunday
# 99439       Monday
# 99440     Thursday
# Name: order_purchase_timestamp, Length: 99441, dtype: object

# %%
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
orders['order_purchase_weekday'] = orders['order_purchase_timestamp'].dt.day_name()

# %%
orders.groupby('')
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
test = orders.merge(items)

# %%
items.dtypes
# Out:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %%
orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# order_purchase_weekday                   object
# dtype: object

# %%
task3 = test.groupby(['product_id','order_purchase_weekday']).agg({'order_id':'count'}).head(25)
task3
# Out:
#                                                          order_id
# product_id                       order_purchase_weekday
# 00066f42aeeb9f3007548bb9d3f33c38 Sunday                         1
# 00088930e925c41fd95ebfe695fd2655 Tuesday                        1
# 0009406fd7479715e4bef61dd91f2462 Thursday                       1
# 000b8f95fcb9e0096488278317764d19 Friday                         1
#                                  Wednesday                      1
# 000d9be29b5207b54e86aa1b1ac54872 Tuesday                        1
# 0011c512eb256aa0dbbb544d8dffcf6e Thursday                       1
# 00126f27c813603687e6ce486d909d01 Sunday                         2
# 001795ec6f1b187d37335e1c4704762e Monday                         2
#                                  Saturday                       3
#                                  Thursday                       1
#                                  Tuesday                        2
# ...

# %%
task3.groupby(['product_id','order_purchase_weekday']).agg({'order_id':'max'})
# Out:
#                                                          order_id
# product_id                       order_purchase_weekday
# 00066f42aeeb9f3007548bb9d3f33c38 Sunday                         1
# 00088930e925c41fd95ebfe695fd2655 Tuesday                        1
# 0009406fd7479715e4bef61dd91f2462 Thursday                       1
# 000b8f95fcb9e0096488278317764d19 Friday                         1
#                                  Wednesday                      1
# 000d9be29b5207b54e86aa1b1ac54872 Tuesday                        1
# 0011c512eb256aa0dbbb544d8dffcf6e Thursday                       1
# 00126f27c813603687e6ce486d909d01 Sunday                         2
# 001795ec6f1b187d37335e1c4704762e Monday                         2
#                                  Saturday                       3
#                                  Thursday                       1
#                                  Tuesday                        2
# ...

# %%
ttest = test.groupby(['product_id','order_purchase_weekday']).size()

# %%
ttest.groupby('product_id').idxmax()
# Out:
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38       (00066f42aeeb9f3007548bb9d3f33c38, Sunday)
# 00088930e925c41fd95ebfe695fd2655      (00088930e925c41fd95ebfe695fd2655, Tuesday)
# 0009406fd7479715e4bef61dd91f2462     (0009406fd7479715e4bef61dd91f2462, Thursday)
# 000b8f95fcb9e0096488278317764d19       (000b8f95fcb9e0096488278317764d19, Friday)
# 000d9be29b5207b54e86aa1b1ac54872      (000d9be29b5207b54e86aa1b1ac54872, Tuesday)
#                                                         ...
# fff6177642830a9a94a0f2cba5e476d1     (fff6177642830a9a94a0f2cba5e476d1, Saturday)
# fff81cc3158d2725c0655ab9ba0f712c       (fff81cc3158d2725c0655ab9ba0f712c, Monday)
# fff9553ac224cec9d15d49f5a263411f       (fff9553ac224cec9d15d49f5a263411f, Friday)
# fffdb2d0ec8d6a61f0a0a0db3f25b441      (fffdb2d0ec8d6a61f0a0a0db3f25b441, Tuesday)
# fffe9eeff12fcbd74a2f2b007dde0c58    (fffe9eeff12fcbd74a2f2b007dde0c58, Wednesday)
# Length: 32951, dtype: object

# %%
ttest = test.groupby(['product_id','order_purchase_weekday']).agg({'order_id':'count'})
ttest
# Out:
#                                                          order_id
# product_id                       order_purchase_weekday
# 00066f42aeeb9f3007548bb9d3f33c38 Sunday                         1
# 00088930e925c41fd95ebfe695fd2655 Tuesday                        1
# 0009406fd7479715e4bef61dd91f2462 Thursday                       1
# 000b8f95fcb9e0096488278317764d19 Friday                         1
#                                  Wednesday                      1
# ...                                                           ...
# fffdb2d0ec8d6a61f0a0a0db3f25b441 Friday                         1
#                                  Sunday                         1
#                                  Thursday                       1
#                                  Tuesday                        2
# fffe9eeff12fcbd74a2f2b007dde0c58 Wednesday                      1
#
# [61230 rows x 1 columns]

# %%
task3 = ttest.groupby(['product_id','order_purchase_weekday']).idxmax()

# %%
del task3['order_id']

# %%
# Решение. Пункт 3
task3
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
#Task 4

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# order_purchase_weekday                   object
# month                                 period[M]
# dtype: object

# %%
orders['month'] = orders['order_purchase_timestamp'].dt.to_period('M')

# %%
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
weeks_per_month = orders.resample('M', on='order_purchase_timestamp')['order_purchase_timestamp'].apply(lambda x: x.dt.isocalendar().week.nunique())

# %%
weeks_per_month
# Out:
# order_purchase_timestamp
# 2016-09-30    3
# 2016-10-31    4
# 2016-11-30    0
# 2016-12-31    1
# 2017-01-31    5
# 2017-02-28    5
# 2017-03-31    5
# 2017-04-30    5
# 2017-05-31    5
# 2017-06-30    5
# 2017-07-31    6
# 2017-08-31    5
# 2017-09-30    5
# 2017-10-31    6
# 2017-11-30    5
# 2017-12-31    5
# 2018-01-31    5
# 2018-02-28    5
# 2018-03-31    5
# 2018-04-30    6
# 2018-05-31    5
# 2018-06-30    5
# 2018-07-31    6
# 2018-08-31    5
# 2018-09-30    4
# 2018-10-31    2
# Freq: M, Name: order_purchase_timestamp, dtype: int64

# %%
wha = pd.DataFrame(weeks_per_month)

# %%
wha
# Out:
#                           order_purchase_timestamp
# order_purchase_timestamp
# 2016-09-30                                       3
# 2016-10-31                                       4
# 2016-11-30                                       0
# 2016-12-31                                       1
# 2017-01-31                                       5
# 2017-02-28                                       5
# 2017-03-31                                       5
# 2017-04-30                                       5
# 2017-05-31                                       5
# 2017-06-30                                       5
# 2017-07-31                                       6
# 2017-08-31                                       5
# 2017-09-30                                       5
# 2017-10-31                                       6
# 2017-11-30                                       5
# 2017-12-31                                       5
# 2018-01-31                                       5
# ...

# %%
purchase_counts = orders.groupby(['customer_id','month']).agg({''})
purchase_counts
# Out:
# customer_id                       month
# 00012a2ce6f8dcda20d059ce98491703  2017-11    1
# 000161a058600d5901f007fab4c27140  2017-07    1
# 0001fd6190edaaf884bcaf3d49edf079  2017-02    1
# 0002414f95344307404f0ace7a26f1d5  2017-08    1
# 000379cdec625522490c315e70c7a9fb  2018-04    1
#                                             ..
# fffecc9f79fd8c764f843e9951b11341  2018-03    1
# fffeda5b6d849fbd39689bb92087f431  2018-05    1
# ffff42319e9b2d713724ae527742af25  2018-06    1
# ffffa3172527f765de70084a7e53aae8  2017-09    1
# ffffe8b65bbe3087b653a978c870db99  2017-09    1
# Length: 99441, dtype: int64

# %%
df_purchase_counts = pd.DataFrame(purchase_counts)

# %%
df_purchase_counts
# Out:
#                                           0
# customer_id                      month
# 00012a2ce6f8dcda20d059ce98491703 2017-11  1
# 000161a058600d5901f007fab4c27140 2017-07  1
# 0001fd6190edaaf884bcaf3d49edf079 2017-02  1
# 0002414f95344307404f0ace7a26f1d5 2017-08  1
# 000379cdec625522490c315e70c7a9fb 2018-04  1
# ...                                      ..
# fffecc9f79fd8c764f843e9951b11341 2018-03  1
# fffeda5b6d849fbd39689bb92087f431 2018-05  1
# ffff42319e9b2d713724ae527742af25 2018-06  1
# ffffa3172527f765de70084a7e53aae8 2017-09  1
# ffffe8b65bbe3087b653a978c870db99 2017-09  1
#
# [99441 rows x 1 columns]

# %%
purchase_counts.dtypes
# Out:
# dtype('int64')

# %%
#purchase_data = pd.merge(weeks_per_month,purchase_counts,left_on='month',right_index=True)
#purchase_data = purchase_counts.to_frame(name='cpurchases').reset_index()
#purchase_data = purchase_data.merge(weeks_per_month.rename('cpurchases'), left_on = 'month',right_index=True)
#purchase_data  = purchase_counts.to_frame()['month'].join(weeks_per_month.to_frame())
#purchase_data = purchase_counts.to_frame(name='cpurchases').join(weeks_per_month.rename('cweeks'))
#purchase_data = purchase_counts.reset_index().join(weeks_per_month)#.rename('cweeks'))
purchase_data = df_purchase_counts.merge(wha.rename('wwww'), left_on='month',right_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-983fbb9c67a5> in <module>
#       5 #purchase_data = purchase_counts.to_frame(name='cpurchases').join(weeks_per_month.rename('cweeks'))
#       6 #purchase_data = purchase_counts.reset_index().join(weeks_per_month)#.rename('cweeks'))
# ----> 7 purchase_data = df_purchase_counts.merge(wha.rename('wwww'), left_on='month',right_index=True)
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     307         @wraps(func)
#     308         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 309             return func(*args, **kwargs)
#     310
#     311         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
# ...

# %%
purchase_data

# %%
№ е
