# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as ss
# %matplotlib inline

# %%
df = pd.read_csv('conversion.csv')

# %%
df.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1

# %%
df.head(50)
# Out:
#      ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0   708746              916          103916  30-34      M        15
# 1   708749              916          103917  30-34      M        16
# 2   708771              916          103920  30-34      M        20
# 3   708815              916          103928  30-34      M        28
# 4   708818              916          103928  30-34      M        28
# 5   708820              916          103929  30-34      M        29
# 6   708889              916          103940  30-34      M        15
# 7   708895              916          103941  30-34      M        16
# 8   708953              916          103951  30-34      M        27
# 9   708958              916          103952  30-34      M        28
# 10  708979              916          103955  30-34      M        31
# 11  709023              916          103962  30-34      M         7
# 12  709038              916          103965  30-34      M        16
# ...

# %%
df.xyz_campaign_id.nunique()
# Out:
# 3

# %%
df.isna().sum()
# Out:
# ad_id                  0
# xyz_campaign_id        0
# fb_campaign_id         0
# age                    0
# gender                 0
# interest               0
# Impressions            0
# Clicks                 0
# Spent                  0
# Total_Conversion       0
# Approved_Conversion    0
# dtype: int64

# %%
df.dtypes
# Out:
# ad_id                    int64
# xyz_campaign_id          int64
# fb_campaign_id           int64
# age                     object
# gender                  object
# interest                 int64
# Impressions              int64
# Clicks                   int64
# Spent                  float64
# Total_Conversion         int64
# Approved_Conversion      int64
# dtype: object

# %%
d = df.fb_campaign_id

# %%
df['new'] = np.log(df['Impressions'])

# %%
df
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion  \
# ...

# %%
sns.distplot(df,x='fb_campaign_id',y='new')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-cf86cccf2655> in <module>
# ----> 1 sns.distplot(df,x='fb_campaign_id',y='new')
#
# TypeError: distplot() got an unexpected keyword argument 'y'

# %%
d = df.groupby('fb_campaign_id').Impressions.sum()

# %%
sns.distplot(d)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df,x=np.log(df['Impressions']), hue='xyz_campaign_id')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-5f4f6f632e30> in <module>
# ----> 1 sns.distplot(df,x=np.log(df['Impressions']), hue='xyz_campaign_id')
#
# TypeError: distplot() got an unexpected keyword argument 'hue'

# %%
df['ctr'] = df.Clicks / df.Impressions

# %%
df
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion  \
# ...

# %%
gg = df.groupby('ad_id',as_index=False).agg({'ctr' : 'sum'})

# %%
gg.sort_values(by='ctr',ascending=False)
# Out:
#       ad_id       ctr
# 150  738637  0.001059
# 440  950224  0.000845
# 505  951779  0.000610
# 476  951202  0.000565
# 448  950537  0.000531
# ..      ...       ...
# 270  777166  0.000000
# 269  777131  0.000000
# 268  777130  0.000000
# 266  776935  0.000000
# 181  747879  0.000000
#
# [1143 rows x 2 columns]

# %%
ctrr = df.query('xyz_campaign_id == "916"').groupby('ad_id',as_index=False).agg({'ctr' : 'sum'})

# %%
ctrr.head()
# Out:
#     ad_id       ctr
# 0  708746  0.000136
# 1  708749  0.000112
# 2  708771  0.000000
# 3  708815  0.000235
# 4  708818  0.000242

# %%
sns.distplot(ctrr,bins=20)

# %%
ctr916
# Out:
# ctr    38333977
# Name: ad_id, dtype: int64

# %%
df.head(50)
# Out:
#      ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0   708746              916          103916  30-34      M        15
# 1   708749              916          103917  30-34      M        16
# 2   708771              916          103920  30-34      M        20
# 3   708815              916          103928  30-34      M        28
# 4   708818              916          103928  30-34      M        28
# 5   708820              916          103929  30-34      M        29
# 6   708889              916          103940  30-34      M        15
# 7   708895              916          103941  30-34      M        16
# 8   708953              916          103951  30-34      M        27
# 9   708958              916          103952  30-34      M        28
# 10  708979              916          103955  30-34      M        31
# 11  709023              916          103962  30-34      M         7
# 12  709038              916          103965  30-34      M        16
# ...

# %%
df['cpc'] = df.Spent / df.Clicks

# %%
df.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion  \
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1
#
#         new       ctr   cpc
# 0  8.902456  0.000136  1.43
# 1  9.790375  0.000112  0.91
# 2  6.541030  0.000000   NaN
# 3  8.356790  0.000235  1.25
# ...

# %%
ss.iqr(df.cpc,nan_policy='omit')
# Out:
# 0.25436369905

# %%
dfna = df.dropna()

# %%
dfna
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# 6      708889              916          103940  30-34      M        15
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion  \
# ...

# %%
sns.distplot(df.cpc)

# %%
df.groupby('gender').agg({'cpc' : 'sum'})
# Out:
#                cpc
# gender
# F       661.626760
# M       741.762451

# %%
tset = df.query('ad_id == 1121814')

# %%
tset
# Out:
#        ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 860  1121814             1178          144659  30-34      F        27
#
#      Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion  \
# 860      2223278     421  612.300003                38                   13
#
#            new       ctr       cpc
# 860  14.614493  0.000189  1.454394

# %%
g = tset.Approved_Conversion / tset.Clicks

# %%
g
# Out:
# 860    0.030879
# dtype: float64
